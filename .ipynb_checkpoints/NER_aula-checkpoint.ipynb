# %% [markdown]
# # Atividade Named-Entity Recognition (NER)
#
# ### Desafio
#
# Crie a rotina para processamento dos textos, preparando os documentos para respeitar a estrutura proposta para rodar uma rede neural capaz de realizar a atividade de reconhecimento de entidades.
#
# Lembre que o resultado deverá ter três colunas (identificador, palavra e tag) como exemplificado na tabela abaixo:
#
# | identificador | palavra | tag |
# |:--:|:--:|:--:|
# |102|tronco|O|
# |102|da|O|
# |102|coronaria|vaso|
# |102|esquerda|vaso|
# |102|com|O|
# |102|trajeto|O|
#
# Você deverá considerar as seguintes classes e termos por classe:
#
# -   **vaso**:
# 	- descendente anterior;
# 	- coronaria direita;
# 	- coronaria esquerda;
# 	- circunflexa;
# 	- primeiro ramo marginal;
# 	- segundo ramo marginal;
# 	- terceiro ramo marginal;
# 	- primeiro ramo diagonal;
# 	- segundo ramo diagonal;
# 	- terceiro ramo diagonal;
# 	- ventricular posterior;
# 	- arteria diagonalis;
# 	- descendente posteiror.
# -   **trajeto**:
# 	- trajeto intramiocardico;
# 	- origem;
# 	- retroaortico;
# 	- interaortopulmonar;
# 	- valsalva;
# 	- seio;
# 	- sinotubular.
# -   **placa**:
# 	- placa;
# 	- placas;
# 	- ateromatose.
# -   **composição**:
# 	- calcificada;
# 	- calcificadas;
# 	- densamente calcificada;
# 	- densamente calcificadas;
# 	- densa;
# 	- densamente calcificado;
# 	- parcialmente calcificada;
# 	- predominantemente calcificada;
# 	- predominantemente calcificadas;
# 	- mista;
# 	- mistas;
# 	- predominantemente nao calcificada;
# 	- predominantemente não calcificada;
# 	- parcialmente não calcificada;
# 	- principalmente calcificada;
# 	- principalmente não calcificada;
# 	- principalmente nao calcificada;
# 	- predominio calcificado;
# 	- predominio nao calcificado;
# 	- não calcificada.
# -   **grau**:
# 	- sem redução luminal;
# 	- discreta;
# 	- irregularidades parietais;
# 	- irregularidade parietal;
# 	- menor que 50%;
# 	- irregularidades luminais;
# 	- irregularidade luminal;
# 	- irregularidade;
# 	- irregularidades;
# 	- proxima de 50%;
# 	- proximo de 50%;
# 	- entre 50 e 70%;
# 	- 50%;
# 	- acima de 50%;
# 	- maior que 50%;
# 	- ao redor de 50%;
# 	- cerca de 50%;
# 	- em torno de 50%;
# 	- acima de 70%;
# 	- 70%;
# 	- cerca de 70%;
# 	- ao redor de 70%;
# 	- em torno de 70%;
# 	- moderada;
# 	- moderada reducao luminal;
# 	- reducao luminal moderada;
# 	- estenose moderada;
# 	- grau pelo menos moderado;
# 	- grau moderado;
# 	- acentuada;
# 	- suboclusao;
# 	- reducao luminal critica;
# 	- estenose critica;
# 	- oclusao;
# 	- ocluido;
# 	- ocluida.
# -   **modificador V**:
# 	- modificador V;
# 	- vulnerabilidade;
# 	- remodelamento positivo;
# 	- baixa atenuação;
# 	- napking ring;
# 	- anel de guardanapo;
# 	- spot calcifications;
# 	- remodelamento arterial positivo.
# -   **stent**:
# 	- stent.
# -   **redução stent**:
# 	- hiperplasia neointimal;
# 	- neointimal;
# 	- proliferação neointimal.
# -   **enxerto**:
# 	- enxerto.

# %%
# Resolução
import numpy as np
import pandas as pd
import re

pd.set_option('display.max_rows', None)

df = pd.read_excel('https://github.com/pgiaeinstein/ner-aula/raw/master/data_coronaria.xlsx')

# %%
df.shape
# Out:
# (439, 1)

# %%
df.head()
# Out:
#                                                texto
# 0  paciente com escore de calcio de zero fase com...
# 1  paciente com escore de calcio de zero fase com...
# 2  paciente com escore de calcio de zero fase com...
# 3  paciente com escore de calcio zero fase com co...
# 4  paciente com escore de calcio de zero fase com...

# %%
reg_vaso = re.compile(r"(descendente anterior|descendente posterior|coronaria (esquerda|direita)|circunflexa|ventricular posterior|arteria diagonalis|((primeiro|segundo|terceiro|quarto)(\se\s|\s))+(ramos?)?\s?(diagon(al|ais)?|margin(al|ais)?)?)")
reg_trajeto = re.compile(r"(trajeto intramiocardico|retroaórtico|interaortopulmonar|valssalva|sinotubular|seio)")
reg_placa = re.compile(r"(placas?|ateromatose)")
reg_desc_placa = re.compile(r"((predominantemente nao |nao |parcialmente |parcialmente nao |predominantemente |principalmente |principalmente nao |densamente )?calcificadas?|mistas?|predominio calcificado|predominio nao calcificado|densamente calcificado|densa)")
reg_oclusao = re.compile(r"(oclusao|suboclusao|acentuada|\b70%?\b|\b50%?\b|moderada\s?(reducao)?\s?(luminal)?|discreta\b|(irregularidades?\s?(pariet(ais|al)|lumin(al|ais))?)|menor que 50%?|maior que 50%?|entre 50%? e 70%?|acima de 50%?|ao redor de 50%?|cerca de 50%?|em torno de 50%?|acima de 70%?|cerca de 70%?|ao redor de 70%?|em torno de 70%?|reducao luminal critica|estenose critica|ocluid(o|a)|reducao luminal moderada|estenose moderada|grau pelo menos moderado|grau moderado|proxima de 50%?|proximo de 50%?)")
reg_modificador = re.compile(r"(modificador v|vulnerabilidade|remodelamento positivo|baixa atenuacao|napking ring|anel de guardanapo|spot calcifications|baixa atenuacao|remodelamento arterial positivo)")
reg_stent = re.compile(r"(stent)")
reg_red_stent = re.compile(r"(proliferacao neointimal|hiperplasia neointimal|hiperplasia|neointimal)")
reg_enxerto = re.compile(r"(enxerto)")

# %%
lista_documentos = df['texto'].tolist()

# %%
def encontra_tags(texto):
    
    lista_retorno = list()
    
    for item in reg_vaso.finditer(texto):
        lista_retorno.append({
            'classe'  : 'vaso',
            'termo'   : item.group(),
            'inicial' : item.start(),
            'final'   : item.end()
        })
    
    for item in reg_trajeto.finditer(texto):
        lista_retorno.append({
            'classe'  : 'trajeto',
            'termo'   : item.group(),
            'inicial' : item.start(),
            'final'   : item.end()
        })
        
    for item in reg_placa.finditer(texto):
        lista_retorno.append({
            'classe'  : 'placa',
            'termo'   : item.group(),
            'inicial' : item.start(),
            'final'   : item.end()
        })
        
    for item in reg_desc_placa.finditer(texto):
        lista_retorno.append({
            'classe'  : 'desc_placa',
            'termo'   : item.group(),
            'inicial' : item.start(),
            'final'   : item.end()
        })
        
    for item in reg_oclusao.finditer(texto):
        lista_retorno.append({
            'classe'  : 'oclusao',
            'termo'   : item.group(),
            'inicial' : item.start(),
            'final'   : item.end()
        })
        
    for item in reg_modificador.finditer(texto):
        lista_retorno.append({
            'classe'  : 'modificador',
            'termo'   : item.group(),
            'inicial' : item.start(),
            'final'   : item.end()
        })
        
    for item in reg_stent.finditer(texto):
        lista_retorno.append({
            'classe'  : 'stent',
            'termo'   : item.group(),
            'inicial' : item.start(),
            'final'   : item.end()
        })
        
    for item in reg_red_stent.finditer(texto):
        lista_retorno.append({
            'classe'  : 'red_stent',
            'termo'   : item.group(),
            'inicial' : item.start(),
            'final'   : item.end()
        })
        
    for item in reg_enxerto.finditer(texto):
        lista_retorno.append({
            'classe'  : 'enxerto',
            'termo'   : item.group(),
            'inicial' : item.start(),
            'final'   : item.end()
        })

    return sorted(lista_retorno, key = lambda x : x['inicial'])

# %%
def parse_texto(texto, lista_tags, indice):
    
    lista_retorno = list()
    lista_tmp = list()
    
    tamanho_texto = len(texto)
    tamanho_lista = len(lista_tags)
    
    ultima_pos = 0
    
    for index, achado in enumerate(lista_tags):
        
        if achado['inicial'] != 0 and index == 0:
            lista_tmp.append((texto[0:achado['inicial']], 'O'))
            ultima_pos = achado['inicial']

        if ultima_pos != achado['inicial']:
            lista_tmp.append((texto[ultima_pos:achado['inicial']], 'O'))
            
        lista_tmp.append((texto[achado['inicial']:achado['final']], achado['classe']))
        ultima_pos = achado['final']
            
        if index + 1 == tamanho_lista:
            lista_tmp.append((texto[ultima_pos:], 'O'))
        
    for item in lista_tmp:
        tag_atual = item[1]
        for palavra in item[0].split(' '):
            if palavra == '':
                continue
            lista_retorno.append({
                'identificador' : indice,
                'palavra'       : palavra,
                'tag'           : tag_atual
            }) 
    
    return lista_retorno

# %%
index = 1
lista_resultante = list()

for documento in lista_documentos:
    lista_tags_documento = encontra_tags(documento)
    lista_resultante.extend(parse_texto(documento, lista_tags_documento, index))
    index += 1

# %%
df_para_nn = pd.DataFrame(lista_resultante)

# %%
df_para_nn.head(200)
# Out:
#      identificador          palavra      tag
# 0                1         paciente        O
# 1                1              com        O
# 2                1           escore        O
# 3                1               de        O
# 4                1           calcio        O
# 5                1               de        O
# 6                1             zero        O
# 7                1             fase        O
# 8                1              com        O
# 9                1        contraste        O
# 10               1        coronaria     vaso
# 11               1         esquerda     vaso
# 12               1        dominante        O
# 13               1           tronco        O
# 14               1               da        O
# 15               1        coronaria     vaso
# 16               1         esquerda     vaso
# 17               1              com        O
# 18               1          trajeto        O
# 19               1                e        O
# 20               1          calibre        O
# 21               1          normais        O
# 22               1       bifurcando        O
# 23               1               em        O
# 24               1      descendente     vaso
# 25               1         anterior     vaso
# 26               1                e        O
# 27               1      circunflexa     vaso
# 28               1          arteria        O
# 29               1      descendente     vaso
# 30               1         anterior     vaso
# 31               1               de        O
# 32               1           grande        O
# 33               1      importancia        O
# 34               1              com        O
# 35               1          trajeto        O
# 36               1                e        O
# 37               1          calibre        O
# 38               1          normais        O
# 39               1         primeiro     vaso
# 40               1          segundo     vaso
# 41               1                e     vaso
# 42               1         terceiro     vaso
# 43               1            ramos     vaso
# 44               1        diagonais     vaso
# 45               1               de        O
# 46               1             fino        O
# 47               1          calibre        O
# 48               1              sem        O
# 49               1          reducao        O
# 50               1          luminal        O
# 51               1          arteria        O
# 52               1      circunflexa     vaso
# 53               1              com        O
# 54               1          trajeto        O
# 55               1                e        O
# 56               1          calibre        O
# 57               1          normais        O
# 58               1         primeiro     vaso
# 59               1             ramo     vaso
# 60               1         marginal     vaso
# 61               1               de        O
# 62               1           grande        O
# 63               1          calibre        O
# 64               1              sem        O
# 65               1          reducao        O
# 66               1          luminal        O
# 67               1          segundo     vaso
# 68               1             ramo     vaso
# 69               1         marginal     vaso
# 70               1               de        O
# 71               1         moderado        O
# 72               1          calibre        O
# 73               1              sem        O
# 74               1          reducao        O
# 75               1          luminal        O
# 76               1         arterias        O
# 77               1      descendente     vaso
# 78               1        posterior     vaso
# 79               1                e        O
# 80               1      ventricular     vaso
# 81               1        posterior     vaso
# 82               1              com        O
# 83               1          trajeto        O
# 84               1                e        O
# 85               1          calibre        O
# 86               1          normais        O
# 87               1        coronaria     vaso
# 88               1          direita     vaso
# 89               1   vascularizando        O
# 90               1           apenas        O
# 91               1                o        O
# 92               1       ventriculo        O
# 93               1          direito        O
# 94               1              com        O
# 95               1          trajeto        O
# 96               1                e        O
# 97               1          calibre        O
# 98               1          normais        O
# 99               2         paciente        O
# 100              2              com        O
# 101              2           escore        O
# 102              2               de        O
# 103              2           calcio        O
# 104              2               de        O
# 105              2             zero        O
# 106              2             fase        O
# 107              2              com        O
# 108              2        contraste        O
# 109              2        coronaria     vaso
# 110              2          direita     vaso
# 111              2        dominante        O
# 112              2           tronco        O
# 113              2               da        O
# 114              2        coronaria     vaso
# 115              2         esquerda     vaso
# 116              2              com        O
# 117              2          trajeto        O
# 118              2                e        O
# 119              2          calibre        O
# 120              2          normais        O
# 121              2       bifurcando        O
# 122              2               em        O
# 123              2      descendente     vaso
# 124              2         anterior     vaso
# 125              2                e        O
# 126              2      circunflexa     vaso
# 127              2          arteria        O
# 128              2      descendente     vaso
# 129              2         anterior     vaso
# 130              2              com        O
# 131              2          trajeto        O
# 132              2                e        O
# 133              2          calibre        O
# 134              2          normais        O
# 135              2         primeiro     vaso
# 136              2                e     vaso
# 137              2          segundo     vaso
# 138              2            ramos     vaso
# 139              2        diagonais     vaso
# 140              2               de        O
# 141              2          pequeno        O
# 142              2          calibre        O
# 143              2            ambos        O
# 144              2              com        O
# 145              2        discretas        O
# 146              2  irregularidades  oclusao
# 147              2        parietais  oclusao
# 148              2        proximais        O
# 149              2          arteria        O
# 150              2      circunflexa     vaso
# 151              2              com        O
# 152              2          trajeto        O
# 153              2                e        O
# 154              2          calibre        O
# 155              2          normais        O
# 156              2         primeiro     vaso
# 157              2             ramo     vaso
# 158              2         marginal     vaso
# 159              2               de        O
# 160              2          pequeno        O
# 161              2          calibre        O
# 162              2              sem        O
# 163              2          reducao        O
# 164              2          luminal        O
# 165              2          segundo     vaso
# 166              2             ramo     vaso
# 167              2         marginal     vaso
# 168              2               de        O
# 169              2           grande        O
# 170              2          calibre        O
# 171              2              sem        O
# 172              2          reducao        O
# 173              2          luminal        O
# 174              2        coronaria     vaso
# 175              2          direita     vaso
# 176              2              com        O
# 177              2          trajeto        O
# 178              2                e        O
# 179              2          calibre        O
# 180              2          normais        O
# 181              2         arterias        O
# 182              2      descendente     vaso
# 183              2        posterior     vaso
# 184              2                e        O
# 185              2      ventricular     vaso
# 186              2        posterior     vaso
# 187              2              com        O
# 188              2          trajeto        O
# 189              2                e        O
# 190              2          calibre        O
# 191              2          normais        O
# 192              3         paciente        O
# 193              3              com        O
# 194              3           escore        O
# 195              3               de        O
# 196              3           calcio        O
# 197              3               de        O
# 198              3             zero        O
# 199              3             fase        O

# %% [markdown]
# ### Modelos

# %%
import pandas as pd
import numpy as np

# data = pd.read_excel("new_output.xlsx")

# %%
data = df_para_nn

# %%
# data = data.fillna(method="ffill")

# %%
data.tail(10)
# Out:
#        identificador        palavra tag
# 48523            439             do   O
# 48524            439          mesmo   O
# 48525            439           lado   O
# 48526            439     compativel   O
# 48527            439            com   O
# 48528            439        sequela   O
# 48529            439             de   O
# 48530            439       complexo   O
# 48531            439  granulomatoso   O
# 48532            439       primario   O

# %%
f'Total de documentos na base: {len(data.identificador.unique())}'
# Out:
# 'Total de documentos na base: 439'

# %%
words = list(set(data["palavra"].values))
words.append("ENDPAD")
n_words = len(words)
n_words
# Out:
# 638

# %%
tags = list(set(data["tag"].values))
n_tags = len(tags)
n_tags
# Out:
# 7

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, t) for w, t in zip(s["palavra"].values.tolist(),
                                                     s["tag"].values.tolist())]
        self.grouped = self.data.groupby("identificador").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["identificador".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)

# %%
sent = getter.get_next()

# %%
sentences = getter.sentences

# %%
max_len = 300
word2idx = {w: i for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
X = [[word2idx[w[0]] for w in s] for s in sentences]

# %%
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=n_words-1)

# %%
word2idx['ENDPAD']
# Out:
# 637

# %%
word2idx
# Out:
# {'tem': 0,
#  'subrramos': 1,
#  'calibroso': 2,
#  'exibe': 3,
#  'fases': 4,
#  '71': 5,
#  'lobo': 6,
#  'menos': 7,
#  'aorta': 8,
#  'maioria': 9,
#  'limiar': 10,
#  'parcial': 11,
#  '75': 12,
#  'intramiocardicos': 13,
#  'padrao': 14,
#  'dilatacoes': 15,
#  'basal': 16,
#  'pervios': 17,
#  'filiforme': 18,
#  'curta': 19,
#  '767': 20,
#  'determinando': 21,
#  'habituais': 22,
#  'identificados': 23,
#  'ate': 24,
#  'opacidade': 25,
#  'sequela': 26,
#  'pulmonares': 27,
#  'pequenas': 28,
#  'adicionais': 29,
#  'logo': 30,
#  'segmento': 31,
#  'predominando': 32,
#  '18': 33,
#  'bastante': 34,
#  'evidente': 35,
#  'percentil': 36,
#  'nos': 37,
#  'demais': 38,
#  'calcificados': 39,
#  'extensao': 40,
#  'observam': 41,
#  '687': 42,
#  'fino': 43,
#  'hilo': 44,
#  'obstrutivas': 45,
#  'pouco': 46,
#  'acima': 47,
#  '179': 48,
#  '187': 49,
#  'provavel': 50,
#  'tendo': 51,
#  'hiato': 52,
#  '50': 53,
#  'seus': 54,
#  '17': 55,
#  'calcificadas': 56,
#  'todas': 57,
#  'disseccoes': 58,
#  'trifurca': 59,
#  'trajeto': 60,
#  'anteriorizada': 61,
#  '163': 62,
#  '191': 63,
#  '25': 64,
#  'positivo': 65,
#  'diminutas': 66,
#  'ramificada': 67,
#  'lesoes': 68,
#  'nao': 69,
#  'estudos': 70,
#  'reducoes': 71,
#  '12': 72,
#  'varredura': 73,
#  'residuais': 74,
#  'porem': 75,
#  'realizada': 76,
#  'raros': 77,
#  'mesmo': 78,
#  'precocemente': 79,
#  'uma': 80,
#  'todo': 81,
#  'tambem': 82,
#  'arteria': 83,
#  'proximal': 84,
#  '219': 85,
#  'para': 86,
#  'com': 87,
#  '23': 88,
#  'tortuoso': 89,
#  'reconstituicao': 90,
#  'intramiocardico': 91,
#  'areas': 92,
#  'passa': 93,
#  'diagonal': 94,
#  'duplicada': 95,
#  'ocorreu': 96,
#  '218': 97,
#  'luz': 98,
#  'direitas': 99,
#  'subcarinal': 100,
#  'igual': 101,
#  'do': 102,
#  'critica': 103,
#  'junto': 104,
#  '126': 105,
#  'da': 106,
#  'movimento': 107,
#  'significativas': 108,
#  'alem': 109,
#  'sinais': 110,
#  'calcificada': 111,
#  'alta': 112,
#  'esparsas': 113,
#  'direcionado': 114,
#  'cisto': 115,
#  'fase': 116,
#  '15': 117,
#  'discretas': 118,
#  'pericardio': 119,
#  'ventricular': 120,
#  '9': 121,
#  'limitada': 122,
#  'trifurcando': 123,
#  'associados': 124,
#  'formacao': 125,
#  'restante': 126,
#  'que': 127,
#  'tronco': 128,
#  'curto': 129,
#  'distais': 130,
#  '91': 131,
#  '31': 132,
#  'infima': 133,
#  'anteromedial': 134,
#  'dos': 135,
#  'ao': 136,
#  'terceiros': 137,
#  'discreta': 138,
#  '310': 139,
#  'proximo': 140,
#  'ambas': 141,
#  'aumento': 142,
#  'distal': 143,
#  'incluidos': 144,
#  'esquerda': 145,
#  'neo': 146,
#  '103': 147,
#  'normal': 148,
#  'cicatricial': 149,
#  'alargamento': 150,
#  'arterias': 151,
#  'tc': 152,
#  'percentis': 153,
#  'a': 154,
#  'delas': 155,
#  'cardiaca': 156,
#  'superficie': 157,
#  'onde': 158,
#  'quantidade': 159,
#  'acompanhada': 160,
#  'linfonodo': 161,
#  'significado': 162,
#  'comum': 163,
#  'ausente': 164,
#  'mediastinais': 165,
#  'parietal': 166,
#  'das': 167,
#  'destacando': 168,
#  'especificos': 169,
#  'diminuto': 170,
#  '37': 171,
#  'frequencia': 172,
#  'pervias': 173,
#  'direito': 174,
#  'lumen': 175,
#  'cm': 176,
#  'minima': 177,
#  'metodo': 178,
#  'abaulamento': 179,
#  'limitam': 180,
#  'entre': 181,
#  'campos': 182,
#  'discreto': 183,
#  'contraste': 184,
#  '6': 185,
#  'achados': 186,
#  'moderado': 187,
#  'especifico': 188,
#  'se': 189,
#  'diagonalis': 190,
#  'primeiro': 191,
#  'quarto': 192,
#  'inacessivel': 193,
#  'medindo': 194,
#  'sido': 195,
#  'raiz': 196,
#  'por': 197,
#  '26': 198,
#  'alguns': 199,
#  'remodelamento': 200,
#  'dois': 201,
#  'triifurcando': 202,
#  'proximais': 203,
#  'terminando': 204,
#  'nodulos': 205,
#  'praticamente': 206,
#  'dominancia': 207,
#  'detectaveis': 208,
#  'preservados': 209,
#  'nasal': 210,
#  'cardiaco': 211,
#  'originando': 212,
#  'discretamente': 213,
#  'apresentam': 214,
#  'arterial': 215,
#  '114': 216,
#  'coronariana': 217,
#  'ha': 218,
#  'faixa': 219,
#  'angulada': 220,
#  'menor': 221,
#  'pelos': 222,
#  'apresenta': 223,
#  'calcificacao': 224,
#  'micronodulo': 225,
#  'liquido': 226,
#  'estendendo': 227,
#  'de': 228,
#  'tercos': 229,
#  'fina': 230,
#  'luminal': 231,
#  'entao': 232,
#  'marginal': 233,
#  'normalidade': 234,
#  'calibres': 235,
#  'parietais': 236,
#  'retroaortico': 237,
#  'diagonais': 238,
#  'caracterizacao': 239,
#  'mamas': 240,
#  'topografia': 241,
#  'inespecifica': 242,
#  'enfisema': 243,
#  'apos': 244,
#  'posterior': 245,
#  '8': 246,
#  'associadas': 247,
#  'irriga': 248,
#  'metade': 249,
#  'lateral': 250,
#  'qual': 251,
#  'filiformes': 252,
#  '24': 253,
#  '151': 254,
#  'emitindo': 255,
#  'proxima': 256,
#  'granulomatoso': 257,
#  '33': 258,
#  '40': 259,
#  'toda': 260,
#  'estudo': 261,
#  'bifurcada': 262,
#  'distribuidas': 263,
#  'sinotubular': 264,
#  'suprindo': 265,
#  'subramo': 266,
#  'as': 267,
#  'calcio': 268,
#  'vaso': 269,
#  'maximo': 270,
#  'artefatos': 271,
#  'contorna': 272,
#  'significativa': 273,
#  'contornando': 274,
#  'estenoses': 275,
#  'lamina': 276,
#  'ambos': 277,
#  '4': 278,
#  'parte': 279,
#  'acentuada': 280,
#  'hilares': 281,
#  'termina': 282,
#  'nodular': 283,
#  '142': 284,
#  'previos': 285,
#  'aparentemente': 286,
#  'esteatose': 287,
#  'coronaria': 288,
#  'anomalo': 289,
#  '120': 290,
#  'outro': 291,
#  'avaliacao': 292,
#  'toracicos': 293,
#  '167': 294,
#  '2': 295,
#  'sistolicas': 296,
#  'data': 297,
#  'muito': 298,
#  'bilaterais': 299,
#  '274': 300,
#  'medio': 301,
#  '111': 302,
#  'cicatriciais': 303,
#  'paredes': 304,
#  'aos': 305,
#  'o': 306,
#  'septo': 307,
#  'associado': 308,
#  'estenosantes': 309,
#  'estende': 310,
#  'ramificados': 311,
#  'compressao': 312,
#  'pelo': 313,
#  'focais': 314,
#  'maior': 315,
#  'intramiocardio': 316,
#  'anterior': 317,
#  'irrigando': 318,
#  'sao': 319,
#  'calcificado': 320,
#  'ter': 321,
#  'sequenciais': 322,
#  'habitual': 323,
#  'hepatica': 324,
#  'oclusao': 325,
#  'apresentando': 326,
#  'reimplantadas': 327,
#  'devendo': 328,
#  '77': 329,
#  'ostial': 330,
#  'vascularizando': 331,
#  'luminais': 332,
#  'irregular': 333,
#  'lado': 334,
#  'seio': 335,
#  'apenas': 336,
#  'algumas': 337,
#  'inter': 338,
#  'densamente': 339,
#  'determinar': 340,
#  'realizado': 341,
#  'aspecto': 342,
#  'tortuosidade': 343,
#  'raras': 344,
#  'predominio': 345,
#  'escore': 346,
#  'sem': 347,
#  'diretamente': 348,
#  '34': 349,
#  'transicao': 350,
#  '42': 351,
#  'centrolobular': 352,
#  '559': 353,
#  'provavelmente': 354,
#  'cerca': 355,
#  'coronariano': 356,
#  'camaras': 357,
#  'dominante': 358,
#  'descendentes': 359,
#  'outros': 360,
#  'expressao': 361,
#  'septal': 362,
#  'virtude': 363,
#  '174': 364,
#  'esofagico': 365,
#  'anatomica': 366,
#  'exuberante': 367,
#  'abaixo': 368,
#  'tenue': 369,
#  'irregularidades': 370,
#  'habitualmente': 371,
#  'terminal': 372,
#  'paciente': 373,
#  'gastrica': 374,
#  '280': 375,
#  'x': 376,
#  'focos': 377,
#  'particularidades': 378,
#  'ostio': 379,
#  'no': 380,
#  'descritos': 381,
#  'tres': 382,
#  'ausencia': 383,
#  '5': 384,
#  'somente': 385,
#  'emergencia': 386,
#  'trifurcado': 387,
#  'terco': 388,
#  'achado': 389,
#  'variante': 390,
#  'cruzando': 391,
#  'na': 392,
#  'segunda': 393,
#  'emissao': 394,
#  '76': 395,
#  'bronquicas': 396,
#  'limitando': 397,
#  'segmentos': 398,
#  'formacoes': 399,
#  'ventriculo': 400,
#  'diastole': 401,
#  '0': 402,
#  'pleural': 403,
#  'continua': 404,
#  'um': 405,
#  'diminuta': 406,
#  'pequenos': 407,
#  'complexo': 408,
#  '29': 409,
#  'dirigido': 410,
#  'inicio': 411,
#  'excentrica': 412,
#  'hipoatenuante': 413,
#  'recente': 414,
#  'assumindo': 415,
#  'deteccao': 416,
#  'difuso': 417,
#  '41': 418,
#  'juncao': 419,
#  'atingir': 420,
#  'valsalva': 421,
#  'calibre': 422,
#  'calcifica': 423,
#  'esquerdo': 424,
#  'pervia': 425,
#  'vascularizado': 426,
#  'redor': 427,
#  'pela': 428,
#  'ectasia': 429,
#  'sexo': 430,
#  'segundo': 431,
#  'associada': 432,
#  'marginais': 433,
#  'mesma': 434,
#  'heterogenea': 435,
#  'pervio': 436,
#  'nodulares': 437,
#  'ou': 438,
#  'compativel': 439,
#  'e': 440,
#  'terceiro': 441,
#  '59': 442,
#  '39': 443,
#  'tenues': 444,
#  'cardiacas': 445,
#  'ramificado': 446,
#  'unica': 447,
#  '177': 448,
#  '131': 449,
#  '13': 450,
#  'azigo': 451,
#  'minimo': 452,
#  'neste': 453,
#  'mista': 454,
#  'como': 455,
#  'nas': 456,
#  'ultrapassando': 457,
#  'sulco': 458,
#  '20': 459,
#  'apex': 460,
#  'cruza': 461,
#  'coracao': 462,
#  'l': 463,
#  'via': 464,
#  '105': 465,
#  'em': 466,
#  'colaterais': 467,
#  'espessamento': 468,
#  'estenose': 469,
#  'duas': 470,
#  'granuloma': 471,
#  'ventriculos': 472,
#  'adicional': 473,
#  'foram': 474,
#  'balanceado': 475,
#  'posteriores': 476,
#  'circunflexa': 477,
#  'primario': 478,
#  'balanceada': 479,
#  'focal': 480,
#  'angulacao': 481,
#  'unico': 482,
#  'predominantemente': 483,
#  'mistas': 484,
#  'importancia': 485,
#  'mas': 486,
#  'menores': 487,
#  'porcao': 488,
#  'sua': 489,
#  'torax': 490,
#  '7': 491,
#  'origem': 492,
#  'determina': 493,
#  'etaria': 494,
#  'nodulo': 495,
#  'aparente': 496,
#  '1': 497,
#  'devido': 498,
#  'moderada': 499,
#  'bifurcacao': 500,
#  'geralmente': 501,
#  'coronarias': 502,
#  'minimas': 503,
#  'fluxo': 504,
#  'clinico': 505,
#  'continuando': 506,
#  'transverso': 507,
#  '28': 508,
#  'longo': 509,
#  'livre': 510,
#  'todos': 511,
#  '10': 512,
#  'corresponder': 513,
#  'ramos': 514,
#  'alongada': 515,
#  'coronarianas': 516,
#  'preservado': 517,
#  'medial': 518,
#  'istmo': 519,
#  '19': 520,
#  'pulmonar': 521,
#  'desprovido': 522,
#  'avaliadas': 523,
#  '168': 524,
#  'parcialmente': 525,
#  '227': 526,
#  'sendo': 527,
#  'finas': 528,
#  'hernia': 529,
#  'evidencias': 530,
#  'placas': 531,
#  '21': 532,
#  'intremiocardico': 533,
#  'aneurismaticas': 534,
#  '275': 535,
#  '906': 536,
#  'ramo': 537,
#  'seu': 538,
#  'normais': 539,
#  'trafega': 540,
#  '200': 541,
#  'longa': 542,
#  'regiao': 543,
#  'atenuacao': 544,
#  'ja': 545,
#  'impressao': 546,
#  'trajetos': 547,
#  'miocardico': 548,
#  '323': 549,
#  '326': 550,
#  'irregularidade': 551,
#  'ainda': 552,
#  'condicionando': 553,
#  'justafissural': 554,
#  'dificil': 555,
#  'evidentes': 556,
#  'saida': 557,
#  'diafragmatico': 558,
#  'atinge': 559,
#  'posteriorizado': 560,
#  'identificam': 561,
#  'segmentar': 562,
#  'leve': 563,
#  'imediatamente': 564,
#  'zero': 565,
#  'relacao': 566,
#  '65': 567,
#  'bifurcado': 568,
#  'derrame': 569,
#  'determinam': 570,
#  'subramos': 571,
#  'inerentes': 572,
#  '47': 573,
#  'circulacao': 574,
#  'desenvolvidas': 575,
#  'outra': 576,
#  'movimentacao': 577,
#  'descendente': 578,
#  'plano': 579,
#  'originam': 580,
#  'parede': 581,
#  'recebendo': 582,
#  'pequena': 583,
#  'previo': 584,
#  'interventricular': 585,
#  'pequeno': 586,
#  'variacao': 587,
#  'duplicidade': 588,
#  'placa': 589,
#  'difusamente': 590,
#  '3': 591,
#  '90': 592,
#  'recesso': 593,
#  'tenha': 594,
#  'diametro': 595,
#  'bifurca': 596,
#  'leito': 597,
#  'mais': 598,
#  'promovem': 599,
#  'quinto': 600,
#  '645': 601,
#  'sitio': 602,
#  'apice': 603,
#  'hiatal': 604,
#  'ateroscleroticas': 605,
#  'partir': 606,
#  'inespecificos': 607,
#  'reducao': 608,
#  'duplicacao': 609,
#  'prejudicada': 610,
#  'esparsos': 611,
#  'exceto': 612,
#  'analise': 613,
#  'primeira': 614,
#  '102': 615,
#  'bifurcando': 616,
#  'ligeiramente': 617,
#  'grande': 618,
#  '428': 619,
#  'os': 620,
#  'predominam': 621,
#  'correspondendo': 622,
#  'toracica': 623,
#  '201': 624,
#  'ultrapassa': 625,
#  '145': 626,
#  'inacessiveis': 627,
#  'linfonodos': 628,
#  '70': 629,
#  'inferior': 630,
#  'atingindo': 631,
#  'direita': 632,
#  '335': 633,
#  'precoce': 634,
#  'outras': 635,
#  'ateromatosas': 636,
#  'ENDPAD': 637}

# %%
X[0]
# Out:
# array([373,  87, 346, 228, 268, 228, 565, 116,  87, 184, 288, 145, 358,
#        128, 106, 288, 145,  87,  60, 440, 422, 539, 616, 466, 578, 317,
#        440, 477,  83, 578, 317, 228, 618, 485,  87,  60, 440, 422, 539,
#        191, 431, 440, 441, 514, 238, 228,  43, 422, 347, 608, 231,  83,
#        477,  87,  60, 440, 422, 539, 191, 537, 233, 228, 618, 422, 347,
#        608, 231, 431, 537, 233, 228, 187, 422, 347, 608, 231, 151, 578,
#        245, 440, 120, 245,  87,  60, 440, 422, 539, 288, 632, 331, 336,
#        306, 400, 174,  87,  60, 440, 422, 539, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637, 637,
#        637], dtype=int32)

# %%
y = [[tag2idx[w[1]] for w in s] for s in sentences]

# %%
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
lista_documentos[1]
# Out:
# 'paciente com escore de calcio de zero fase com contraste coronaria direita dominante tronco da coronaria esquerda com trajeto e calibre normais bifurcando em descendente anterior e circunflexa arteria descendente anterior com trajeto e calibre normais primeiro e segundo ramos diagonais de pequeno calibre ambos com discretas irregularidades parietais proximais arteria circunflexa com trajeto e calibre normais primeiro ramo marginal de pequeno calibre sem reducao luminal segundo ramo marginal de grande calibre sem reducao luminal coronaria direita com trajeto e calibre normais arterias descendente posterior e ventricular posterior com trajeto e calibre normais'

# %%
y[1]
# Out:
# array([6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 3, 3, 6, 6, 6, 3, 3, 6, 6, 6, 6, 6,
#        6, 6, 3, 3, 6, 3, 6, 3, 3, 6, 6, 6, 6, 6, 3, 3, 3, 3, 3, 6, 6, 6,
#        6, 6, 6, 1, 1, 6, 6, 3, 6, 6, 6, 6, 6, 3, 3, 3, 6, 6, 6, 6, 6, 6,
#        3, 3, 3, 6, 6, 6, 6, 6, 6, 3, 3, 6, 6, 6, 6, 6, 6, 3, 3, 6, 3, 3,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6], dtype=int32)

# %%
tag2idx
# Out:
# {'trajeto': 0,
#  'oclusao': 1,
#  'desc_placa': 2,
#  'vaso': 3,
#  'modificador': 4,
#  'placa': 5,
#  'O': 6}

# %%
from tensorflow.keras.utils import to_categorical

# %%
y = [to_categorical(i, num_classes=n_tags) for i in y]

# %%
from sklearn.model_selection import train_test_split

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.1, random_state=6)

# %% [markdown]
# ### BI LSTM

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional

# %%
input = Input(shape=(max_len,))
model = Embedding(input_dim=n_words, output_dim=32, input_length=max_len)(input)
model = Dropout(0.1)(model)
model = Bidirectional(LSTM(units=64, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(n_tags, activation="softmax"))(model)

# %%
model = Model(input, out)

# %%
model.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(X_tr, np.array(y_tr), batch_size=32, epochs=15, validation_split=0.1, verbose=1)
# Out:
# Train on 355 samples, validate on 40 samples
# Epoch 1/15
# 355/355 [==============================] - 6s 16ms/sample - loss: 1.0133 - accuracy: 0.8184 - val_loss: 0.3677 - val_accuracy: 0.8999
# Epoch 2/15
# 355/355 [==============================] - 3s 8ms/sample - loss: 0.3475 - accuracy: 0.8955 - val_loss: 0.2885 - val_accuracy: 0.8999
# Epoch 3/15
# 355/355 [==============================] - 3s 9ms/sample - loss: 0.3024 - accuracy: 0.8955 - val_loss: 0.2758 - val_accuracy: 0.8999
# Epoch 4/15
# 355/355 [==============================] - 3s 9ms/sample - loss: 0.2927 - accuracy: 0.8955 - val_loss: 0.2677 - val_accuracy: 0.8999
# Epoch 5/15
# 355/355 [==============================] - 4s 10ms/sample - loss: 0.2802 - accuracy: 0.8955 - val_loss: 0.2579 - val_accuracy: 0.8999
# Epoch 6/15
# 355/355 [==============================] - 4s 12ms/sample - loss: 0.2685 - accuracy: 0.8955 - val_loss: 0.2412 - val_accuracy: 0.8999
# Epoch 7/15
# 355/355 [==============================] - 4s 12ms/sample - loss: 0.2481 - accuracy: 0.8969 - val_loss: 0.2171 - val_accuracy: 0.9034
# Epoch 8/15
# 355/355 [==============================] - 4s 12ms/sample - loss: 0.2204 - accuracy: 0.9132 - val_loss: 0.1853 - val_accuracy: 0.9355
# Epoch 9/15
# 355/355 [==============================] - 4s 12ms/sample - loss: 0.1850 - accuracy: 0.9463 - val_loss: 0.1494 - val_accuracy: 0.9636
# Epoch 10/15
# 355/355 [==============================] - 4s 11ms/sample - loss: 0.1481 - accuracy: 0.9722 - val_loss: 0.1147 - val_accuracy: 0.9816
# Epoch 11/15
# 355/355 [==============================] - 4s 11ms/sample - loss: 0.1153 - accuracy: 0.9775 - val_loss: 0.0907 - val_accuracy: 0.9817
# Epoch 12/15
# 355/355 [==============================] - 4s 12ms/sample - loss: 0.0933 - accuracy: 0.9782 - val_loss: 0.0811 - val_accuracy: 0.9829
# Epoch 13/15
# 355/355 [==============================] - 4s 12ms/sample - loss: 0.0781 - accuracy: 0.9792 - val_loss: 0.0668 - val_accuracy: 0.9818
# Epoch 14/15
# 355/355 [==============================] - 4s 11ms/sample - loss: 0.0679 - accuracy: 0.9807 - val_loss: 0.0599 - val_accuracy: 0.9880
# Epoch 15/15
# 355/355 [==============================] - 4s 12ms/sample - loss: 0.0591 - accuracy: 0.9835 - val_loss: 0.0493 - val_accuracy: 0.9858

# %%
from seqeval.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
test_pred = model.predict(X_te, verbose=1)
# Out:
# 44/44 [==============================] - 0s 8ms/sample

# %%
idx2tag = {i: w for w, i in tag2idx.items()}

def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i].replace("ENDPAD", "O"))
        out.append(out_i)
    return out
    
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_te)

# %%
print("ACC      : {:.4%}".format(accuracy_score(test_labels, pred_labels)))
print("PRECISION: {:.4%}".format(precision_score(test_labels, pred_labels)))
print("RECALL   : {:.4%}".format(recall_score(test_labels, pred_labels)))
print("F1       : {:.4%}".format(f1_score(test_labels, pred_labels)))
# Out:
# ACC      : 98.5985%
# PRECISION: 81.9444%
# RECALL   : 79.0179%
# F1       : 80.4545%

# %%
print(classification_report(test_labels, pred_labels))
# Out:
#              precision    recall  f1-score   support
#
#     trajeto       0.00      0.00      0.00        20
#  desc_placa       0.20      0.12      0.15        34
#       placa       0.00      0.00      0.00        34
#        vaso       0.85      0.95      0.90       534
#     oclusao       0.70      0.39      0.50        49
# modificador       0.00      0.00      0.00         1
#
#   micro avg       0.82      0.79      0.80       672
#   macro avg       0.73      0.79      0.76       672

# %% [markdown]
# ### BI-LSTM-CRF

# %%
import keras

# %%
keras.__version__
# Out:
# '2.3.1'

# %%
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-6009dd8a7b59> in <module>
#       1 from keras.models import Model, Input
#       2 from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
# ----> 3 from keras_contrib.layers import CRF
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# /usr/local/lib/python3.7/dist-packages/tf_keras_contrib-2.0.8-py3.7.egg/keras_contrib/__init__.py in <module>
#       2 from . import backend
#       3 from . import datasets
# ----> 4 from . import layers
#       5 from . import preprocessing
#       6 from . import utils
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# /usr/local/lib/python3.7/dist-packages/tf_keras_contrib-2.0.8-py3.7.egg/keras_contrib/layers/__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from .advanced_activations.pelu import PELU
#       4 from .advanced_activations.srelu import SReLU
#       5 from .advanced_activations.swish import Swish
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# /usr/local/lib/python3.7/dist-packages/tf_keras_contrib-2.0.8-py3.7.egg/keras_contrib/layers/advanced_activations/pelu.py in <module>
#       2 from tensorflow.keras import initializers, regularizers, constraints
#       3 import tensorflow.keras.backend as K
# ----> 4 from keras_contrib.utils.test_utils import to_tuple
#       5
#       6
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# /usr/local/lib/python3.7/dist-packages/tf_keras_contrib-2.0.8-py3.7.egg/keras_contrib/utils/test_utils.py in <module>
#     186     is_tf_keras = True
#     187 else:
# --> 188     raise KeyError('Cannot detect if using keras or tf.keras.')
#     189
#     190
#
# KeyError: 'Cannot detect if using keras or tf.keras.'

# %%
input = Input(shape=(max_len,))
model = Embedding(input_dim=n_words + 1, output_dim=32, input_length=max_len, mask_zero=True)(input)
model = Bidirectional(LSTM(units=64, return_sequences=True, recurrent_dropout=0.1))(model)
# model = TimeDistributed(Dense(64, activation="relu"))(model)
crf = CRF(n_tags)
out = crf(model)

# %%
model = Model(input, out)

# %%
model.compile(optimizer="rmsprop", loss=crf.loss_function, metrics=[crf.accuracy])

# %%
model.summary()

# %%
history = model.fit(X_tr, np.array(y_tr), batch_size=32, epochs=15, validation_split=0.1, verbose=1)

# %%
hist = pd.DataFrame(history.history)

# %%
from seqeval.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
test_pred = model.predict(X_te, verbose=1)

# %%
idx2tag = {i: w for w, i in tag2idx.items()}

def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i].replace("ENDPAD", "O"))
        out.append(out_i)
    return out
    
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_te)

# %%
print("ACC      : {:.4%}".format(accuracy_score(test_labels, pred_labels)))
print("PRECISION: {:.4%}".format(precision_score(test_labels, pred_labels)))
print("RECALL   : {:.4%}".format(recall_score(test_labels, pred_labels)))
print("F1       : {:.4%}".format(f1_score(test_labels, pred_labels)))

# %%
print(classification_report(test_labels, pred_labels))
